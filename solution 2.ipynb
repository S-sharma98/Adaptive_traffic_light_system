# %%
import time
import sys

T=int(input("total during of cycle"))

while True:
    a=int(input("no of vehicle="))
    m =a*4
    if a<5:
        time1=10
        print("time1",+time1)
    else:
        if m>70:
            time1=70
            print("time1",+time1)
        else:
            time1=m
            print("time1",+time1)

    time2=time1
    time3=140
    time4=210
    print("time2",+time2)
    print("time3",+time3)
    print("time4",+time4)
    
    H=(T-time1)/3
    
    b=int(input("enter no of vehicle"))
    n=b*4
    if b <5:
        time2=10
        print("time2",+time2)
    else:
        if n>70:
            time2=70
            print("time2",+time2)
        else:
            time2=n
            print("time2",+time2)
     
    profit_loss=(T-time1)/3-time2
    
    time3=time2
    time4=210-time2
    time1=210
    
    print("time3",+time3)
    print("time4",+time4)
    print("time1",+time1)
    
    
    #G is time in second trial
    G=H +0.5* profit_loss
    
    c=int(input("enter no of vehicle"))
    t=c*4
    if c <5:
        time3=10
        print("time3",+time3)
    else:
        if t>70:
            time3=70
            print("time3",+time3)
        else:
            time3=t
            print('time3',+time3)
        
    profit_loss2=G-time3
    
    time4=time3
    time1=210-time3
    time2=210
    
    print("time4",+time4)
    print("time1",+time1)
    print("time2",+time2)
    
    
    d=int(input("enter no of vehicle"))
    l=d*4
    if d<5:
        time4<10
        print("time4",+time4)
    else:
        if l>70:
            time4=70
            print("time4",+time4)
        else:
            time4=l
            print("time4",+time4)
    
                 
    time1=time4
    time2=210-time4
    time3=210
    
    print(time1)
    print(time2)
    print(time3)
